# %% [markdown]
# # Double 7's (Short Term Trading Strategies that Work)
#
#     1. The Security is above its 200-day moving average or X-day ma
#     2. The Security closes at a 7-day low, buy.
#     3. If the Security closes at a 7-day high, sell your long position.

# %%
import datetime

import matplotlib.pyplot as plt
import pandas as pd

import pinkfish as pf
import strategy

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# %matplotlib inline

# %%
# Set size of inline plots.
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# Some global data

# %%
#symbol = '^GSPC'
symbol = 'SPY'
#symbol = 'DIA'
#symbol = 'QQQ'
#symbol = 'IWM'
#symbol = 'TLT'
#symbol = 'GLD'
#symbol = 'AAPL'
#symbol = 'BBRY'
#symbol = 'GDX'
#symbol = 'OIH'
#symbol = 'NLY'

capital = 10000
#start = datetime.datetime(2015, 1, 1)
start = datetime.datetime(*pf.SP500_BEGIN)
end = datetime.datetime.now()

# %% [markdown]
# Run Strategy

# %%
# options = {
#     'use_adj' : False,
#     'use_cache' : True,
#     'stop_loss_pct' : 0.15,
#     'margin' : 2.0,
#     'period' : 7,
#     'sma' : 70,
#     'use_regime_filter' : True
# }

options = {
    'use_adj' : False,
    'use_cache' : True,
    'stop_loss_pct' : 0.15,
    'margin' : 2,
    'period' : 7,
    'sma' : 70,
    'use_regime_filter' : True
}

s = strategy.Strategy(symbol, capital, start, end, options)
s.run()

# %% [markdown]
# View logs

# %%
s.tlog.tail()
# Out:
#     entry_date  entry_price  exit_date  exit_price  pl_points   pl_cash   qty  \
# 346 2026-02-03       689.53 2026-02-25      693.15       3.62  13451.90  3716
# 347 2026-03-03       680.33 2026-04-06      658.93     -21.40 -81427.09  3805
# 348 2026-05-19       733.73 2026-05-26      750.59      16.86  55739.31  3306
# 349 2026-06-05       737.55 2026-06-15      754.83      17.28  59443.30  3440
# 350 2026-06-23       733.58 2026-06-26      734.94       1.36   4917.21  3621
#
#      cumul_total direction symbol
# 346   1284603.02      LONG    SPY
# 347   1203175.93      LONG    SPY
# 348   1258915.24      LONG    SPY
# 349   1318358.55      LONG    SPY
# 350   1323275.76      LONG    SPY

# %%
s.dbal.tail()
# Out:
#                  high        low      close  shares        cash  leverage  \
# date
# 2026-06-22 1328358.55 1328358.55 1328358.55       0  1328358.55      1.00
# 2026-06-23 1328358.55 1328358.55 1328358.55    3621 -1327934.70      2.00
# 2026-06-24 1327127.31 1327127.31 1327127.31    3621 -1327934.70      2.00
# 2026-06-25 1330965.56 1330965.56 1330965.56    3621 -1327934.70      2.00
# 2026-06-26 1333275.76 1333275.76 1333275.76       0  1333275.76      1.00
#
#            state
# date
# 2026-06-22     -
# 2026-06-23     O
# 2026-06-24     -
# 2026-06-25     -
# 2026-06-26     X

# %% [markdown]
# Generate strategy stats - display all available stats

# %%
pf.print_full(s.stats)
# Out:
# start                                                   1993-11-11
# end                                                     2026-06-26
# beginning_balance                                            10000
# ending_balance                                          1333275.76
# total_net_profit                                        1323275.76
# gross_profit                                            2630088.15
# gross_loss                                             -1306812.39
# profit_factor                                                 2.01
# return_on_initial_capital                                 13232.76
# annual_return_rate                                           16.18
# trading_period                           32 years 7 months 15 days
# pct_time_in_market                                           32.42
# margin                                                           2
# avg_leverage                                                  1.33
# max_leverage                                                  2.39
# min_leverage                                                  1.00
# total_num_trades                                               351
# trades_per_year                                              10.76
# num_winning_trades                                             273
# num_losing_trades                                               77
# num_even_trades                                                  1
# pct_profitable_trades                                        77.78
# avg_profit_per_trade                                       3770.02
# avg_profit_per_winning_trade                               9634.02
# avg_loss_per_losing_trade                                -16971.59
# ratio_avg_profit_win_loss                                     0.57
# largest_profit_winning_trade                              59464.74
# largest_loss_losing_trade                                -85470.01
# num_winning_points                                          878.22
# num_losing_points                                          -394.05
# total_net_points                                            484.17
# avg_points                                                    1.38
# largest_points_winning_trade                                 18.28
# largest_points_losing_trade                                 -25.86
# avg_pct_gain_per_trade                                        0.74
# largest_pct_winning_trade                                     6.92
# largest_pct_losing_trade                                     -7.64
# expected_shortfall                                           -6.89
# max_consecutive_winning_trades                                  18
# max_consecutive_losing_trades                                    3
# avg_bars_winning_trades                                       6.53
# avg_bars_losing_trades                                       15.88
# max_closed_out_drawdown                                     -28.09
# max_closed_out_drawdown_peak_date                       2011-07-19
# max_closed_out_drawdown_trough_date                     2011-08-08
# max_closed_out_drawdown_recovery_date                   2011-12-09
# drawdown_loss_period                                            20
# drawdown_recovery_period                                       123
# annualized_return_over_max_drawdown                           0.58
# max_intra_day_drawdown                                      -28.09
# avg_yearly_closed_out_drawdown                              -14.31
# max_yearly_closed_out_drawdown                              -28.09
# avg_monthly_closed_out_drawdown                              -3.31
# max_monthly_closed_out_drawdown                             -28.09
# avg_weekly_closed_out_drawdown                               -1.09
# max_weekly_closed_out_drawdown                              -26.02
# avg_yearly_closed_out_runup                                  30.50
# max_yearly_closed_out_runup                                  97.36
# avg_monthly_closed_out_runup                                  4.43
# max_monthly_closed_out_runup                                 28.01
# avg_weekly_closed_out_runup                                   1.44
# max_weekly_closed_out_runup                                  17.80
# pct_profitable_years                                         83.36
# best_year                                                    95.33
# worst_year                                                  -25.07
# avg_year                                                     17.59
# annual_std                                                   18.94
# pct_profitable_months                                        56.46
# best_month                                                   28.01
# worst_month                                                 -27.26
# avg_month                                                     1.30
# monthly_std                                                   4.52
# pct_profitable_weeks                                         31.63
# best_week                                                    17.80
# worst_week                                                  -26.02
# avg_week                                                      0.33
# weekly_std                                                    2.64
# pct_profitable_days                                          18.24
# best_day                                                     12.52
# worst_day                                                   -14.49
# avg_day                                                       0.07
# daily_std                                                     1.34
# sharpe_ratio                                                  0.81
# sharpe_ratio_max                                              0.85
# sharpe_ratio_min                                              0.78
# sortino_ratio                                                 0.64
# dtype: object

# %% [markdown]
# Run Benchmark, Retrieve benchmark logs, and Generate benchmark stats

# %%
benchmark = pf.Benchmark(symbol, capital, s.start, s.end, use_adj=True)
benchmark.run()

# %% [markdown]
# Plot Equity Curves: Strategy vs Benchmark

# %%
pf.plot_equity_curve(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Plot Trades

# %%
pf.plot_trades(s.dbal, benchmark=benchmark.dbal)

# %% [markdown]
# Bar Graph: Strategy vs Benchmark

# %%
df = pf.plot_bar_graph(s.stats, benchmark.stats)
df
# Out:
#                                      strategy  benchmark
# annual_return_rate                      16.18      10.79
# max_closed_out_drawdown                -28.09     -55.16
# annualized_return_over_max_drawdown      0.58       0.20
# best_month                              28.01      23.59
# worst_month                            -27.26     -30.98
# sharpe_ratio                             0.81       0.64
# sortino_ratio                            0.64       0.82
# monthly_std                              4.52       4.48
# annual_std                              18.94      16.92

# %% [markdown]
# Plot Instrument Risk vs Strategy Risk

# %%
df = pf.volatility_graphs([s.ts, s.dbal], [symbol, 'Strategy'], points_to_plot=5000)
df
# Out:
#         SPY  Strategy
# avg    0.16      0.16
# median 0.13      0.14
# min    0.03      0.00
# max    0.96      0.96
# std    0.11      0.14
# last   0.17      0.21

# %% [markdown]
# Prettier Graphs

# %%
returns = s.dbal['close']
benchmark_returns = benchmark.dbal['close']
pf.prettier_graphs(returns, benchmark_returns, dbal_label='Strategy', benchmark_label='Benchmark', points_to_plot=5000)

# %%
pf.kelly_criterion(s.stats, benchmark.stats)
# Out:
# sharpe_ratio            0.81
# sharpe_ratio_max        0.85
# sharpe_ratio_min        0.78
# strategy risk           0.19
# instrument risk         0.17
# optimal target risk     0.81
# half kelly criterion    0.41
# aggressive leverage     4.81
# moderate leverage       2.41
# conservative leverage   2.29
# dtype: float64
